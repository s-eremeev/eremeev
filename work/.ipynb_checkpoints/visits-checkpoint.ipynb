# %% [markdown]
# # Посещение врачей

# %%
import pandas as pd
import numpy as np

# игнорирование предупреждения о формате при импорте из excel
import warnings

# warnings.simplefilter("ignore")

# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %% [markdown]
# ISO-8859-1

# %% [markdown]
# # Если нестандартные кодировки:

# %%
# загрузка файла для ЕАО !!!
df_data = pd.read_csv(
    "/home/sk27/work/med/data/source.csv",
    sep=";",
    encoding="utf-16",
    low_memory=False,
)

# %%
# загрузка справочников
f_032 = pd.read_excel("/home/sk27/work/med/data/F032.xlsx")
v_021 = pd.read_excel("/home/sk27/work/med/data/V021.xlsx")
v_002 = pd.read_excel("/home/sk27/work/med/data/V002.xlsx")
v_006 = pd.read_excel("/home/sk27/work/med/data/V006.xlsx")
v_025 = pd.read_excel("/home/sk27/work/med/data/V025.xlsx")
oid_data = pd.read_excel("/home/sk27/work/med/data/oid_data.xlsx")

# актуализация справочников
f_032 = f_032[["OKTMO_P", "SUBJ"]].drop_duplicates().reset_index(drop=True)
v_021 = v_021[v_021["DATEEND"].isna()]
v_002 = v_002[v_002["DATEEND"].isna()]
v_006 = v_006[v_006["DATEEND"].isna()]
v_025 = v_025[v_025["DATEEND"].isna()]

# %% [markdown]
# ## Заголовок добавить вручную
# ### Переходить сразу к расшифровке кодов

# %%
df_data
# Out:
#        year  month  region        oktmo  clinic  \
# 0      2023      1      99  99000000000  790001
# 1      2023      1      99  99000000000  790001
# 2      2023      1      99  99000000000  790001
# 3      2023      1      99  99000000000  790001
# 4      2023      1      99  99000000000  790001
# ...     ...    ...     ...          ...     ...
# 25405  2023      2      99  99000000000  790021
# 25406  2023      2      99  99000000000  790021
# 25407  2023      2      99  99000000000  790021
# 25408  2023      2      99  99000000000  790021
# 25409  2023      2      99  99000000000  790021
#
#                                   oid    depart  branch  doctor_specialty  \
# 0      1.2.643.5.1.13.13.12.2.79.8850  79000100     NaN                24
# 1      1.2.643.5.1.13.13.12.2.79.8850  79000100     NaN                24
# 2      1.2.643.5.1.13.13.12.2.79.8850  79000100     NaN                24
# 3      1.2.643.5.1.13.13.12.2.79.8850  79000100     NaN                24
# 4      1.2.643.5.1.13.13.12.2.79.8850  79000100     NaN                24
# ...                               ...       ...     ...               ...
# 25405  1.2.643.5.1.13.13.12.2.79.8838  79002100     NaN                41
# 25406  1.2.643.5.1.13.13.12.2.79.8838  79002100     NaN                45
# 25407  1.2.643.5.1.13.13.12.2.79.8838  79002100     NaN                76
# 25408  1.2.643.5.1.13.13.12.2.79.8838  79002100     NaN                76
# 25409  1.2.643.5.1.13.13.12.2.79.8838  79002100     NaN               206
#
#        doctor_profile  ...  purpose      service_id  usl_service_id  \
# 0                  28  ...      1.0     B01.014.001  137-097-107 64
# 1                  28  ...      1.3  R03.03.102.001  137-097-107 64
# 2                  28  ...      1.0     B01.014.001  137-097-107 64
# 3                  28  ...      3.0     B01.014.002  137-097-107 64
# 4                  28  ...      3.0     B01.014.002  138-993-968 45
# ...               ...  ...      ...             ...             ...
# 25405              60  ...      1.0     B01.027.001     17717264189
# 25406             162  ...      1.0     B01.028.001     13109077827
# 25407              97  ...      1.0     B01.047.001      6180038532
# 25408              97  ...      1.0     B01.047.001      6180038532
# 25409              42  ...      2.6           26.73      7044889275
#
#        usl_doctor_specialty usl_clinic usl_depart  sl_id  code_usl  kol_usl  \
# 0                        24     790001   79000100      1         1        1
# 1                        24     790001   79000100      1         1        1
# 2                        24     790001   79000100     10         1        1
# 3                        24     790001   79000100     12         5        1
# 4                        24     790001   79000100      2        15        1
# ...                     ...        ...        ...    ...       ...      ...
# 25405                    41     790021   79002100      2         3        1
# 25406                    45     790021   79002100      1         1        1
# 25407                    76     790021   79002100      1         1        1
# 25408                    76     790021   79002100      1         1        1
# 25409                   206     790021   79002100    240         1        1
#
#        yet_sum
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 25405      NaN
# 25406      NaN
# 25407      NaN
# 25408      NaN
# 25409      NaN
#
# [25410 rows x 23 columns]

# %%
df_data.shape
# Out:
# (25410, 23)

# %%
df_data[df_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [year, month, region, oktmo, clinic, oid, depart, branch, doctor_specialty, doctor_profile, terms, doctor_id, diagnosis, purpose, service_id, usl_service_id, usl_doctor_specialty, usl_clinic, usl_depart, sl_id, code_usl, kol_usl, yet_sum]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_data[df_data.duplicated()].shape
# Out:
# (0, 23)

# %% [markdown]
# # Обычные кодировки
# ## 1. Подготовка данных

# %%
# %%time

# вспомогательные функции

def oktmo(o):
    """
    функция дополняет код ОКТМО до 11 символов или до 10 символов без ведущего 0
    """
    if len(str(o)) == 1:
        l = 9
    else:
        l = 11-len(str(o))
    return int(str(o) + "0"*(l))
    
def visit_count(row):
    """
    функция определяет количество посещений согласно условиям
    """
    if row["purpose"] >= 3:
        res = row["code_usl"] * row["kol_usl"]
    else:
        res = row["sl_id"]
    if np.isnan(res):
        return "не определено"
    else:
        return res
    
# загрузка справочников
f_032 = pd.read_excel("/home/sk27/work/med/data/F032.xlsx")
v_021 = pd.read_excel("/home/sk27/work/med/data/V021.xlsx")
v_002 = pd.read_excel("/home/sk27/work/med/data/V002.xlsx")
v_006 = pd.read_excel("/home/sk27/work/med/data/V006.xlsx")
v_025 = pd.read_excel("/home/sk27/work/med/data/V025.xlsx")
oid_data = pd.read_excel("/home/sk27/work/med/data/oid_data.xlsx")

# актуализация справочников
f_032 = f_032[["OKTMO_P", "SUBJ"]].drop_duplicates().reset_index(drop=True)
v_021 = v_021[v_021["DATEEND"].isna()]
v_002 = v_002[v_002["DATEEND"].isna()]
v_006 = v_006[v_006["DATEEND"].isna()]
v_025 = v_025[v_025["DATEEND"].isna()]


# добавление в файл данных строки заголовков
with open("/home/sk27/work/med/data/source.csv", "r") as f:
    first_line = next(f).strip()
    if first_line[0:4] != "year":
        with open(
            "/home/sk27/work/med/data/source.csv", "r", encoding="ISO-8859-1"
        ) as original:
            data = original.read()
        with open("/home/sk27/work/med/data/source.csv", "w") as modified:
            modified.write(
                "year;month;region;clinic;oid;depart;branch;doctor_specialty;doctor_profile;terms;doctor_id;diagnosis;purpose;service_id;usl_service_id;usl_doctor_specialty;usl_clinic;usl_depart;sl_id;code_usl;kol_usl;yet_sum\n"
                + data
            )
    else:
        pass


# загрузка файла
df_data = pd.read_csv(
    "/home/sk27/work/med/data/source.csv",
    sep=";",
    encoding="ISO-8859-1",
    low_memory=False,
)

# УДАЛЕНИЕ ДУБЛИКАТОВ СТРОК
df_data = df_data.drop_duplicates()

# удаление кавычек
for i, col in enumerate(df_data.columns):
    df_data.iloc[:, i] = df_data.iloc[:, i].astype("str").str.replace('"', "")
# df_data = df_data.apply(pd.to_numeric, errors="ignore")

# замена ВСЕХ запятых точками
for i, col in enumerate(df_data.columns):
    df_data.iloc[:, i] = df_data.iloc[:, i].astype("str").str.replace(',', ".")
df_data = df_data.apply(pd.to_numeric, errors="ignore")

# вставка столбца ОКТМО
df_data.insert(3, "oktmo", df_data["region"].apply(oktmo))

# проверка загруженных данных

# а) проверка количества столбцов - их должно быть именно 23 вместе с добавленным мной столбцом ОКТМО
if df_data.shape[1] > 23:
    print(f"Количество полей в файле (их {df_data.shape[1]}) не соответствует форме отчёта, должно быть 23.")
else:
    pass

# б) проверка столбца terms на "только 3"
try:
    if df_data["terms"].mean() != 3:
        print(
            "Нарушено требование об указании в поле 'Условия оказания медпомощи' только значения '3'."
        )
except:
    print("Не проходит проверка на '3'")
    
# расшифровка кодов
# Out:
# CPU times: user 50.6 s, sys: 224 ms, total: 50.8 s
# Wall time: 50.9 s

# %%
df_data.head(10)
# Out:
#    year  month  region        oktmo  clinic                             oid  \
# 0  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 1  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 2  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 3  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 4  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 5  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 6  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 7  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 8  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
# 9  2023      1      99  99000000000  790001  1.2.643.5.1.13.13.12.2.79.8850
#
#      depart  branch  doctor_specialty  doctor_profile  ...  purpose  \
# 0  79000100     NaN                24              28  ...      1.0
# 1  79000100     NaN                24              28  ...      1.3
# 2  79000100     NaN                24              28  ...      1.0
# 3  79000100     NaN                24              28  ...      3.0
# 4  79000100     NaN                24              28  ...      3.0
# 5  79000100     NaN                24              28  ...      1.0
# 6  79000100     NaN                24              28  ...      1.0
# 7  79000100     NaN                24              28  ...      3.0
# 8  79000100     NaN                24              28  ...      3.0
# 9  79000100     NaN                24              28  ...      3.0
#
#        service_id  usl_service_id  usl_doctor_specialty usl_clinic usl_depart  \
# 0     B01.014.001  137-097-107 64                    24     790001   79000100
# 1  R03.03.102.001  137-097-107 64                    24     790001   79000100
# 2     B01.014.001  137-097-107 64                    24     790001   79000100
# 3     B01.014.002  137-097-107 64                    24     790001   79000100
# 4     B01.014.002  138-993-968 45                    24     790001   79000100
# 5     B01.014.001  137-097-107 64                    24     790001   79000100
# 6     B01.014.001  137-097-107 64                    24     790001   79000100
# 7     B01.014.001  137-097-107 64                    24     790001   79000100
# 8     B01.014.002  137-097-107 64                    24     790001   79000100
# 9     B01.014.002  137-097-107 64                    24     790001   79000100
#
#    sl_id  code_usl  kol_usl  yet_sum
# 0      1         1        1      NaN
# 1      1         1        1      NaN
# 2     10         1        1      NaN
# 3     12         5        1      NaN
# 4      2        15        1      NaN
# 5      1         1        1      NaN
# 6      1         1        1      NaN
# 7      1         4        1      NaN
# 8      7         3        1      NaN
# 9      3         3        1      NaN
#
# [10 rows x 23 columns]

# %%
df_data.shape
# Out:
# (25410, 23)

# %%
df_data[df_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [year, month, region, oktmo, clinic, oid, depart, branch, doctor_specialty, doctor_profile, terms, doctor_id, diagnosis, purpose, service_id, usl_service_id, usl_doctor_specialty, usl_clinic, usl_depart, sl_id, code_usl, kol_usl, yet_sum]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ## 2. Расшифровка кодов

# %%
# расшифорвка названия субьекта Росссийской Федерации
df_data = df_data.merge(f_032, left_on="oktmo", right_on="OKTMO_P", how="left")

# %%
df_data = df_data[
    [
        "year",
        "month",
        "region",
        "oktmo",
        "SUBJ",
        "clinic",
        "oid",
        "depart",
        "branch",
        "doctor_specialty",
        "doctor_profile",
        "terms",
        "doctor_id",
        "diagnosis",
        "purpose",
        "service_id",
        "usl_service_id",
        "usl_doctor_specialty",
        "usl_clinic",
        "usl_depart",
        "sl_id",
        "code_usl",
        "kol_usl",
        "yet_sum",
    ]
].reset_index(drop=True)

# %%
df_data = df_data.drop_duplicates()

# %%
df_data.shape
# Out:
# (25410, 24)

# %%
# расшифровка наименования (сокращённого) медучреждения
df_data = df_data.merge(oid_data, left_on="oid", right_on="oid", how="left")

# %%
df_data = df_data[
    [
        "year",
        "month",
        "region",
        "oktmo",
        "SUBJ",
        "clinic",
        "oid",
        "nameShort",
        "depart",
        "branch",
        "doctor_specialty",
        "doctor_profile",
        "terms",
        "doctor_id",
        "diagnosis",
        "purpose",
        "service_id",
        "usl_service_id",
        "usl_doctor_specialty",
        "usl_clinic",
        "usl_depart",
        "sl_id",
        "code_usl",
        "kol_usl",
        "yet_sum",
    ]
].reset_index(drop=True)

# %%
df_data.shape
# Out:
# (25410, 25)

# %%
# расшифровка специальности врача
df_data = df_data.merge(
    v_021, left_on="doctor_specialty", right_on="IDSPEC", how="left"
)

# %%
df_data = df_data[
    [
        "year",
        "month",
        "region",
        "oktmo",
        "SUBJ",
        "clinic",
        "oid",
        "nameShort",
        "depart",
        "branch",
        "doctor_specialty",
        "POSTNAME",
        "doctor_profile",
        "terms",
        "doctor_id",
        "diagnosis",
        "purpose",
        "service_id",
        "usl_service_id",
        "usl_doctor_specialty",
        "usl_clinic",
        "usl_depart",
        "sl_id",
        "code_usl",
        "kol_usl",
        "yet_sum",
    ]
].reset_index(drop=True)

# %%
df_data.shape
# Out:
# (25410, 26)

# %%
# расшифровка профиля врача
df_data = df_data.merge(v_002, left_on="doctor_profile", right_on="IDPR", how="left")

# %%
df_data = df_data[
    [
        "year",
        "month",
        "region",
        "oktmo",
        "SUBJ",
        "clinic",
        "oid",
        "nameShort",
        "depart",
        "branch",
        "doctor_specialty",
        "POSTNAME",
        "doctor_profile",
        "PRNAME",
        "terms",
        "doctor_id",
        "diagnosis",
        "purpose",
        "service_id",
        "usl_service_id",
        "usl_doctor_specialty",
        "usl_clinic",
        "usl_depart",
        "sl_id",
        "code_usl",
        "kol_usl",
        "yet_sum",
    ]
].reset_index(drop=True)

# %%
df_data.shape
# Out:
# (25410, 27)

# %%
# расшифровка специальности врача, оказавшего услугу
df_data = df_data.merge(
    v_021, left_on="doctor_specialty", right_on="IDSPEC", how="left"
)

# %%
df_data = df_data[
    [
        "year",
        "month",
        "region",
        "oktmo",
        "SUBJ",
        "clinic",
        "oid",
        "nameShort",
        "depart",
        "branch",
        "doctor_specialty",
        "POSTNAME_x",
        "doctor_profile",
        "PRNAME",
        "terms",
        "doctor_id",
        "diagnosis",
        "purpose",
        "service_id",
        "usl_service_id",
        "usl_doctor_specialty",
        "POSTNAME_y",
        "usl_clinic",
        "usl_depart",
        "sl_id",
        "code_usl",
        "kol_usl",
        "yet_sum",
    ]
].reset_index(drop=True)

# %%
df_data.shape
# Out:
# (25410, 28)

# %%
# расшифровка условий оказания помощи
df_data = df_data.merge(v_006, left_on="terms", right_on="IDUMP", how="left")

# %%
df_data = df_data[
    [
        "year",
        "month",
        "region",
        "oktmo",
        "SUBJ",
        "clinic",
        "oid",
        "nameShort",
        "depart",
        "branch",
        "doctor_specialty",
        "POSTNAME_x",
        "doctor_profile",
        "PRNAME",
        "terms",
        "UMPNAME",
        "doctor_id",
        "diagnosis",
        "purpose",
        "service_id",
        "usl_service_id",
        "usl_doctor_specialty",
        "POSTNAME_y",
        "usl_clinic",
        "usl_depart",
        "sl_id",
        "code_usl",
        "kol_usl",
        "yet_sum",
    ]
].reset_index(drop=True)

# %%
df_data.shape
# Out:
# (25410, 29)

# %%
# расшифровка цели посещения
df_data = df_data.merge(v_025, left_on="purpose", right_on="IDPC", how="left")

# %%
df_data = df_data[
    [
        "year",
        "month",
        "region",
        "oktmo",
        "SUBJ",
        "clinic",
        "oid",
        "nameShort",
        "depart",
        "branch",
        "doctor_specialty",
        "POSTNAME_x",
        "doctor_profile",
        "PRNAME",
        "terms",
        "UMPNAME",
        "doctor_id",
        "diagnosis",
        "purpose",
        "N_PC",
        "service_id",
        "usl_service_id",
        "usl_doctor_specialty",
        "POSTNAME_y",
        "usl_clinic",
        "usl_depart",
        "sl_id",
        "code_usl",
        "kol_usl",
        "yet_sum",
    ]
].reset_index(drop=True)

# %%
df_data.shape
# Out:
# (25410, 30)

# %%
df_data
# Out:
#        year  month  region        oktmo          SUBJ  clinic  \
# 0      2023      1      99  99000000000  Еврейская АО  790001
# 1      2023      1      99  99000000000  Еврейская АО  790001
# 2      2023      1      99  99000000000  Еврейская АО  790001
# 3      2023      1      99  99000000000  Еврейская АО  790001
# 4      2023      1      99  99000000000  Еврейская АО  790001
# ...     ...    ...     ...          ...           ...     ...
# 25405  2023      2      99  99000000000  Еврейская АО  790021
# 25406  2023      2      99  99000000000  Еврейская АО  790021
# 25407  2023      2      99  99000000000  Еврейская АО  790021
# 25408  2023      2      99  99000000000  Еврейская АО  790021
# 25409  2023      2      99  99000000000  Еврейская АО  790021
#
#                                   oid                         nameShort  \
# 0      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# 1      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# 2      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# 3      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# 4      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# ...                               ...                               ...
# 25405  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
# 25406  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
# 25407  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
# 25408  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
# 25409  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
#
#          depart  branch  ...      service_id  usl_service_id  \
# 0      79000100     NaN  ...     B01.014.001  137-097-107 64
# 1      79000100     NaN  ...  R03.03.102.001  137-097-107 64
# 2      79000100     NaN  ...     B01.014.001  137-097-107 64
# 3      79000100     NaN  ...     B01.014.002  137-097-107 64
# 4      79000100     NaN  ...     B01.014.002  138-993-968 45
# ...         ...     ...  ...             ...             ...
# 25405  79002100     NaN  ...     B01.027.001     17717264189
# 25406  79002100     NaN  ...     B01.028.001     13109077827
# 25407  79002100     NaN  ...     B01.047.001      6180038532
# 25408  79002100     NaN  ...     B01.047.001      6180038532
# 25409  79002100     NaN  ...           26.73      7044889275
#
#        usl_doctor_specialty              POSTNAME_y  usl_clinic usl_depart  \
# 0                        24       врач-инфекционист      790001   79000100
# 1                        24       врач-инфекционист      790001   79000100
# 2                        24       врач-инфекционист      790001   79000100
# 3                        24       врач-инфекционист      790001   79000100
# 4                        24       врач-инфекционист      790001   79000100
# ...                     ...                     ...         ...        ...
# 25405                    41            врач-онколог      790021   79002100
# 25406                    45  врач-оториноларинголог      790021   79002100
# 25407                    76           врач-терапевт      790021   79002100
# 25408                    76           врач-терапевт      790021   79002100
# 25409                   206               фельдшер       790021   79002100
#
#       sl_id code_usl  kol_usl yet_sum
# 0         1        1        1     NaN
# 1         1        1        1     NaN
# 2        10        1        1     NaN
# 3        12        5        1     NaN
# 4         2       15        1     NaN
# ...     ...      ...      ...     ...
# 25405     2        3        1     NaN
# 25406     1        1        1     NaN
# 25407     1        1        1     NaN
# 25408     1        1        1     NaN
# 25409   240        1        1     NaN
#
# [25410 rows x 30 columns]

# %% [markdown]
# ## 3. Расчёт количества посещений

# %%
# определение количества посещений
df_data["visit_count"] = df_data.apply(visit_count, axis=1)

# %%
df_data
# Out:
#        year  month  region        oktmo          SUBJ  clinic  \
# 0      2023      1      99  99000000000  Еврейская АО  790001
# 1      2023      1      99  99000000000  Еврейская АО  790001
# 2      2023      1      99  99000000000  Еврейская АО  790001
# 3      2023      1      99  99000000000  Еврейская АО  790001
# 4      2023      1      99  99000000000  Еврейская АО  790001
# ...     ...    ...     ...          ...           ...     ...
# 25405  2023      2      99  99000000000  Еврейская АО  790021
# 25406  2023      2      99  99000000000  Еврейская АО  790021
# 25407  2023      2      99  99000000000  Еврейская АО  790021
# 25408  2023      2      99  99000000000  Еврейская АО  790021
# 25409  2023      2      99  99000000000  Еврейская АО  790021
#
#                                   oid                         nameShort  \
# 0      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# 1      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# 2      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# 3      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# 4      1.2.643.5.1.13.13.12.2.79.8850          ОГБУЗ Областная больница
# ...                               ...                               ...
# 25405  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
# 25406  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
# 25407  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
# 25408  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
# 25409  1.2.643.5.1.13.13.12.2.79.8838  ОГБУЗ "Онкологический диспансер"
#
#          depart  branch  ...  usl_service_id usl_doctor_specialty  \
# 0      79000100     NaN  ...  137-097-107 64                   24
# 1      79000100     NaN  ...  137-097-107 64                   24
# 2      79000100     NaN  ...  137-097-107 64                   24
# 3      79000100     NaN  ...  137-097-107 64                   24
# 4      79000100     NaN  ...  138-993-968 45                   24
# ...         ...     ...  ...             ...                  ...
# 25405  79002100     NaN  ...     17717264189                   41
# 25406  79002100     NaN  ...     13109077827                   45
# 25407  79002100     NaN  ...      6180038532                   76
# 25408  79002100     NaN  ...      6180038532                   76
# 25409  79002100     NaN  ...      7044889275                  206
#
#                    POSTNAME_y usl_clinic  usl_depart sl_id code_usl kol_usl  \
# 0           врач-инфекционист     790001    79000100     1        1       1
# 1           врач-инфекционист     790001    79000100     1        1       1
# 2           врач-инфекционист     790001    79000100    10        1       1
# 3           врач-инфекционист     790001    79000100    12        5       1
# 4           врач-инфекционист     790001    79000100     2       15       1
# ...                       ...        ...         ...   ...      ...     ...
# 25405            врач-онколог     790021    79002100     2        3       1
# 25406  врач-оториноларинголог     790021    79002100     1        1       1
# 25407           врач-терапевт     790021    79002100     1        1       1
# 25408           врач-терапевт     790021    79002100     1        1       1
# 25409               фельдшер      790021    79002100   240        1       1
#
#        yet_sum visit_count
# 0          NaN           1
# 1          NaN           1
# 2          NaN          10
# 3          NaN           5
# 4          NaN          15
# ...        ...         ...
# 25405      NaN           2
# 25406      NaN           1
# 25407      NaN           1
# 25408      NaN           1
# 25409      NaN         240
#
# [25410 rows x 31 columns]

# %% [markdown]
# ## 4. Контроль результатов

# %%
# формат данных
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25410 entries, 0 to 25409
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  25410 non-null  int64
#  1   month                 25410 non-null  int64
#  2   region                25410 non-null  int64
#  3   oktmo                 25410 non-null  int64
#  4   SUBJ                  25410 non-null  object
#  5   clinic                25410 non-null  int64
#  6   oid                   25410 non-null  object
#  7   nameShort             25410 non-null  object
#  8   depart                25410 non-null  int64
#  9   branch                377 non-null    float64
#  10  doctor_specialty      25410 non-null  int64
#  11  POSTNAME_x            25410 non-null  object
#  12  doctor_profile        25410 non-null  int64
#  13  PRNAME                25410 non-null  object
#  14  terms                 25410 non-null  int64
#  15  UMPNAME               25410 non-null  object
#  16  doctor_id             25410 non-null  object
#  17  diagnosis             25410 non-null  object
#  18  purpose               25410 non-null  float64
#  19  N_PC                  25410 non-null  object
#  20  service_id            25410 non-null  object
#  21  usl_service_id        25410 non-null  object
#  22  usl_doctor_specialty  25410 non-null  int64
#  23  POSTNAME_y            25410 non-null  object
#  24  usl_clinic            25410 non-null  int64
#  25  usl_depart            25410 non-null  int64
#  26  sl_id                 25410 non-null  int64
#  27  code_usl              25410 non-null  int64
#  28  kol_usl               25410 non-null  int64
#  29  yet_sum               533 non-null    float64
#  30  visit_count           25410 non-null  int64
# dtypes: float64(3), int64(16), object(12)
# memory usage: 6.0+ MB

# %%
# пустые количества посещений
df_data[np.isnan(df_data["visit_count"])]
# Out:
# Empty DataFrame
# Columns: [year, month, region, oktmo, SUBJ, clinic, oid, nameShort, depart, branch, doctor_specialty, POSTNAME_x, doctor_profile, PRNAME, terms, UMPNAME, doctor_id, diagnosis, purpose, N_PC, service_id, usl_service_id, usl_doctor_specialty, POSTNAME_y, usl_clinic, usl_depart, sl_id, code_usl, kol_usl, yet_sum, visit_count]
# Index: []
#
# [0 rows x 31 columns]

# %%
# не определённые количества посещений
df_data[df_data["visit_count"] == "не определено"]
# Out:
# Empty DataFrame
# Columns: [year, month, region, oktmo, SUBJ, clinic, oid, nameShort, depart, branch, doctor_specialty, POSTNAME_x, doctor_profile, PRNAME, terms, UMPNAME, doctor_id, diagnosis, purpose, N_PC, service_id, usl_service_id, usl_doctor_specialty, POSTNAME_y, usl_clinic, usl_depart, sl_id, code_usl, kol_usl, yet_sum, visit_count]
# Index: []
#
# [0 rows x 31 columns]

# %%
# сохранение результатов на диск
df_data.to_csv("/home/sk27/work/med/data/result.csv", encoding="utf-8-sig")

# %% [markdown]
# ## Исследование дубликатов
# На примере денных Коми за февраль

# %%
with open("/home/sk27/work/med/new/11_komy/022023.csv", "r") as f:
    first_line = next(f).strip()
    if first_line[0:4] != "year":
        with open(
            "/home/sk27/work/med/new/11_komy/022023.csv", "r", encoding="ISO-8859-1"
        ) as original:
            data = original.read()
        with open("/home/sk27/work/med/new/11_komy/022023.csv", "w") as modified:
            modified.write(
                "year;month;region;clinic;oid;depart;branch;doctor_specialty;doctor_profile;terms;doctor_id;diagnosis;purpose;service_id;usl_service_id;usl_doctor_specialty;usl_clinic;usl_depart;sl_id;code_usl;kol_usl;yet_sum\n"
                + data
            )
    else:
        pass
df_test = pd.read_csv(
    "/home/sk27/work/med/new/11_komy/022023.csv",
    sep=";",
    encoding="ISO-8859-1",
    low_memory=False,
)

# %%
df_test = df_test.fillna(0)

# %%
df_test.shape
# Out:
# (146942, 22)

# %%
df_test[df_test.duplicated()].shape
# Out:
# (355, 22)

# %%
df_test_nodup = df_test.drop_duplicates()

# %%
df_test_nodup.shape
# Out:
# (146587, 22)

# %%
df_test_nodup
# Out:
#         year  month  region  clinic                            oid    depart  \
# 0       2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 1       2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 2       2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 3       2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 4       2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# ...      ...    ...     ...     ...                            ...       ...
# 146937  2023      2   87000  110065  1.2.643.5.1.13.13.12.2.11.778  11006500
# 146938  2023      2   87000  110065  1.2.643.5.1.13.13.12.2.11.778  11006500
# 146939  2023      2   87000  110065  1.2.643.5.1.13.13.12.2.11.778  11006500
# 146940  2023      2   87000  110065  1.2.643.5.1.13.13.12.2.11.778  11006500
# 146941  2023      2   87000  110065  1.2.643.5.1.13.13.12.2.11.778  11006500
#
#         branch  doctor_specialty  doctor_profile  terms  ... purpose  \
# 0          0.0                 2             136      3  ...     1.0
# 1          0.0                 2             136      3  ...     1.0
# 2          0.0                 2             136      3  ...     3.0
# 3          0.0                 2             136      3  ...     3.0
# 4          0.0                 2             136      3  ...     3.0
# ...        ...               ...             ...    ...  ...     ...
# 146937     0.0               208              85      3  ...     3.0
# 146938     0.0               208              85      3  ...     3.0
# 146939     0.0               208              85      3  ...     3.0
# 146940     0.0               208              85      3  ...     3.0
# 146941     0.0               208              85      3  ...     3.0
#
#              service_id  usl_service_id usl_doctor_specialty usl_clinic  \
# 0           B01.001.001  035-508-952 59                    2     110001
# 1           B01.001.001  035-508-952 59                    2     110001
# 2           B01.001.001  035-508-952 59                    2     110001
# 3           B01.001.001  035-508-952 59                    2     110001
# 4           B01.001.001  073-069-750 73                    2     110001
# ...                 ...             ...                  ...        ...
# 146937   A16.07.025.001  131-143-489 14                  208     110065
# 146938       A16.07.051  131-143-489 14                  208     110065
# 146939  B01.003.004.004  131-143-489 14                  208     110065
# 146940      B01.065.003  131-143-489 14                  208     110065
# 146941      B01.065.004  131-143-489 14                  208     110065
#
#         usl_depart  sl_id  code_usl  kol_usl  yet_sum
# 0         11000100      1         1        1     0.00
# 1         11000100      4         1        1     0.00
# 2         11000100      3         1        1     0.00
# 3         11000100      2         2        1     0.00
# 4         11000100      1         1        1     0.00
# ...            ...    ...       ...      ...      ...
# 146937    11006500      1         1        1     0.20
# 146938    11006500      1         1        1     2.00
# 146939    11006500      1         1        1     0.31
# 146940    11006500      1         1        1     1.68
# 146941    11006500      1         1        1     1.18
#
# [146587 rows x 22 columns]

# %%
df_test.columns
# Out:
# Index(['year', 'month', 'region', 'clinic', 'oid', 'depart', 'branch',
#        'doctor_specialty', 'doctor_profile', 'terms', 'doctor_id', 'diagnosis',
#        'purpose', 'service_id', 'usl_service_id', 'usl_doctor_specialty',
#        'usl_clinic', 'usl_depart', 'sl_id', 'code_usl', 'kol_usl', 'yet_sum'],
#       dtype='object')

# %%
df_test_group = df_test.groupby(
    [
        "year",
        "month",
        "region",
        "clinic",
        "oid",
        "depart",
        "branch",
        "doctor_specialty",
        "doctor_profile",
        "terms",
        "doctor_id",
        "diagnosis",
        "purpose",
        "service_id",
        "usl_service_id",
        "usl_doctor_specialty",
        "usl_clinic",
        "usl_depart",
    ]
).agg({"sl_id": "sum", "code_usl": "sum", "kol_usl": "sum", "yet_sum": "sum"})

# %%
df_test_group = df_test_group.reset_index()

# %%
df_test.head(10)
# Out:
#    year  month  region  clinic                            oid    depart  \
# 0  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 1  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 2  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 3  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 4  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 5  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 6  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 7  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 8  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
# 9  2023      2   87000  110001  1.2.643.5.1.13.13.12.2.11.724  11000100
#
#    branch  doctor_specialty  doctor_profile  terms  ... purpose   service_id  \
# 0     0.0                 2             136      3  ...     1.0  B01.001.001
# 1     0.0                 2             136      3  ...     1.0  B01.001.001
# 2     0.0                 2             136      3  ...     3.0  B01.001.001
# 3     0.0                 2             136      3  ...     3.0  B01.001.001
# 4     0.0                 2             136      3  ...     3.0  B01.001.001
# 5     0.0                 2             136      3  ...     3.0  B01.001.002
# 6     0.0                 2             136      3  ...     3.0  B01.001.002
# 7     0.0                 2             136      3  ...     3.0  B01.001.001
# 8     0.0                 2             136      3  ...     3.0  B01.001.002
# 9     0.0                 2             136      3  ...     3.0  B01.001.001
#
#    usl_service_id usl_doctor_specialty usl_clinic  usl_depart  sl_id  \
# 0  035-508-952 59                    2     110001    11000100      1
# 1  035-508-952 59                    2     110001    11000100      4
# 2  035-508-952 59                    2     110001    11000100      3
# 3  035-508-952 59                    2     110001    11000100      2
# 4  073-069-750 73                    2     110001    11000100      1
# 5  035-508-952 59                    2     110001    11000100      4
# 6  035-508-952 59                    2     110001    11000100      1
# 7  035-508-952 59                    2     110001    11000100      1
# 8  035-508-952 59                    2     110001    11000100      1
# 9  035-508-952 59                    2     110001    11000100      1
#
#    code_usl  kol_usl  yet_sum
# 0         1        1      0.0
# 1         1        1      0.0
# 2         1        1      0.0
# 3         2        1      0.0
# 4         1        1      0.0
# 5         1        1      0.0
# 6         4        1      0.0
# 7         1        1      0.0
# 8         2        1      0.0
# 9         1        1      0.0
#
# [10 rows x 22 columns]

# %%
df_test_group.head(10)
# Out:
#    year  month  region  clinic                            oid    depart  \
# 0  2022      9   87000  110035  1.2.643.5.1.13.13.12.2.11.758  11003505
# 1  2022      9   87000  110044  1.2.643.5.1.13.13.12.2.11.733  11004415
# 2  2022     11   87000  110044  1.2.643.5.1.13.13.12.2.11.733  11004415
# 3  2022     12   87000  110011  1.2.643.5.1.13.13.12.2.11.756  11001100
# 4  2022     12   87000  110016  1.2.643.5.1.13.13.12.2.11.702  11001600
# 5  2022     12   87000  110035  1.2.643.5.1.13.13.12.2.11.758  11003508
# 6  2022     12   87000  110037  1.2.643.5.1.13.13.12.2.11.738  11003708
# 7  2022     12   87000  110037  1.2.643.5.1.13.13.12.2.11.738  11003708
# 8  2022     12   87000  110049  1.2.643.5.1.13.13.12.2.11.752  11004944
# 9  2022     12   87000  110051  1.2.643.5.1.13.13.12.2.11.765  11005100
#
#    branch  doctor_specialty  doctor_profile  terms  ... purpose   service_id  \
# 0     0.0                79             100      3  ...     3.0  B01.050.001
# 1     0.0                92             122      3  ...     3.0  B01.058.001
# 2     0.0                92             122      3  ...     3.0  B01.058.001
# 3     0.0                35             158      3  ...     3.0  B01.031.002
# 4     0.0                79             100      3  ...     3.0  B01.050.002
# 5     0.0                25              29      3  ...     3.0  B01.015.001
# 6     0.0                17              16      3  ...     3.0  B01.008.001
# 7     0.0                79             100      3  ...     3.0  B01.050.001
# 8     0.0                76              97      3  ...     3.0  B01.047.005
# 9     0.0                 2             136      3  ...     3.0  B01.001.004
#
#    usl_service_id usl_doctor_specialty usl_clinic  usl_depart  sl_id  \
# 0  073-703-876 74                   79     110035    11003505      1
# 1  056-635-703 76                   92     110044    11004415      1
# 2  056-635-703 76                   92     110044    11004415      1
# 3  005-922-854 44                  104     110011    11001100      1
# 4  127-630-334 43                   79     110016    11001600      1
# 5  127-325-262 41                   25     110035    11003508      1
# 6  113-481-084 25                   17     110037    11003708      1
# 7  152-504-576 43                   79     110037    11003708      1
# 8  135-358-129 58                   76     110049    11004944      1
# 9  215-943-213 57                    2     110051    11005100      1
#
#    code_usl  kol_usl  yet_sum
# 0         1        1      0.0
# 1         1        1      0.0
# 2         1        1      0.0
# 3         1        1      0.0
# 4         2        1      0.0
# 5         1        1      0.0
# 6         1        1      0.0
# 7         1        1      0.0
# 8         1        1      0.0
# 9         1        1      0.0
#
# [10 rows x 22 columns]

# %%
def visit_count(row):
    """
    функция определяет количество посещений согласно условиям
    """
    if row["purpose"] >= 3:
        res = row["code_usl"] * row["kol_usl"]
    else:
        res = row["sl_id"]
    if np.isnan(res):
        return "не определено"
    else:
        return res

# %%
df_test["visit_count"] = df_test.apply(visit_count, axis=1)

# %%
df_test_group["visit_count"] = df_test_group.apply(visit_count, axis=1)

# %%
df_test_nodup["visit_count"] = df_test.apply(visit_count, axis=1)

# %%
df_test["visit_count"].sum()
# Out:
# 358095

# %%
df_test_group["visit_count"].sum()
# Out:
# 483241

# %%
df_test_nodup["visit_count"].sum()
# Out:
# 357656

# %%
df_test.shape
# Out:
# (146942, 23)

# %%
df_test_group.shape
# Out:
# (128501, 23)

# %%
df_test_nodup.shape
# Out:
# (146587, 23)

# %%
df_test.visit_count.describe()
# Out:
# count    146942.000000
# mean          2.436982
# std           8.576010
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max        1061.000000
# Name: visit_count, dtype: float64

# %%
df_test_nodup.visit_count.describe()
# Out:
# count    146587.000000
# mean          2.439889
# std           8.586147
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max        1061.000000
# Name: visit_count, dtype: float64

# %%
df_test_group.visit_count.describe()
# Out:
# count    128501.000000
# mean          3.760601
# std          13.629208
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max        1061.000000
# Name: visit_count, dtype: float64

# %%
df_test.loc[1]
# Out:
# year                                             2023
# month                                               2
# region                                          87000
# clinic                                         110001
# oid                     1.2.643.5.1.13.13.12.2.11.724
# depart                                       11000100
# branch                                            0.0
# doctor_specialty                                    2
# doctor_profile                                    136
# terms                                               3
# doctor_id                              035-508-952 59
# diagnosis                                       D25.9
# purpose                                           1.0
# service_id                                B01.001.001
# usl_service_id                         035-508-952 59
# usl_doctor_specialty                                2
# usl_clinic                                     110001
# usl_depart                                   11000100
# sl_id                                               4
# code_usl                                            1
# kol_usl                                             1
# yet_sum                                           0.0
# visit_count                                         4
# Name: 1, dtype: object

# %% [markdown]
# ***

# %% [markdown]
# [Работа с Excel](https://realpython.com/openpyxl-excel-spreadsheets-python/)

# %%
from openpyxl import load_workbook

# %%
workbook = load_workbook(filename="/home/sk27/work/med/data/F032.xlsx")
workbook.sheetnames
# Out:
# ['Справочник']

# %%
sheet = workbook.active
sheet
# Out:
# <Worksheet "Справочник">

# %%
for value in sheet.iter_rows(
    min_row=1, max_row=2, min_col=1, max_col=10, values_only=True
):
    print(value)
# Out:
# ('UIDMO', 'IDMO', 'MCOD', 'OKTMO_P', 'SUBJ', 'D_BEGIN', 'D_END', 'NAME_E', 'DATEBEG', 'DATEEND')
# ('01202201101000000', '00003503000000007', '010078', '79000000000', 'Республика Адыгея', datetime.datetime(2021, 8, 19, 0, 0), None, None, datetime.datetime(2022, 1, 1, 0, 0), datetime.datetime(2022, 10, 11, 0, 0))
