# %% [markdown]
# # Копия расчётов дашборда

# %%
# %%time

import pandas as pd

df_test = pd.read_csv('C:/work/files/error.csv', sep=';', dtype=object, header=None)
df_tech_error = df_test.loc[(df_test[4].isin(['1', '2', '5', '10', '12'])) & (df_test[11]=='3')]
df_tech_error = pd.DataFrame(df_tech_error.groupby(1)[5].count()).reset_index()
df_org_error = df_test.loc[(df_test[4]=='8') & (df_test[11]=='3')]
df_org_error = pd.DataFrame(df_org_error.groupby(1)[5].count()).reset_index()
df_regions = pd.DataFrame(df_test[1]).drop_duplicates().drop(index=0).reset_index(drop=True)
df_errors = df_regions.merge(df_tech_error, left_on=1, right_on=1, how='left').merge(df_org_error, left_on=1, right_on=1, how='left')
df_errors = df_errors.rename(columns={1: 'region_name', '5_x': 'tech_errors', '5_y': 'org_errors'})
df_errors = df_errors.fillna(0)
df_errors[['tech_errors', 'org_errors']] = df_errors[['tech_errors', 'org_errors']].astype('int')
df_test = pd.read_csv('C:/work/files/good.csv', sep=';', dtype=object, header=None)
df_suc = pd.DataFrame(df_test.loc[df_test[8]=='3'].groupby(2).count()[0]).reset_index()
df_full = df_errors.merge(df_suc, left_on='region_name', right_on=2, how='left').rename(columns={0: 'success'})[['region_name', 'success', 'tech_errors', 'org_errors']].fillna(0)
df_full['success'] = df_full['success'].astype('int')
df_full = df_full.sort_values('region_name').reset_index(drop=True)
print('\n\n\tКоличество успешных запписей, организационных и технических ошибок по субъектам\n')
print(df_full.to_string(index=True))
# Out:
# 	Количество успешных запписей, организационных и технических ошибок по субъектам
#
#                                  region_name  success  tech_errors  org_errors
# 0                             Алтайский край     2734          255         463
# 1                           Амурская область      226          466          52
# 2                      Архангельская область      305           73         287
# 3                       Астраханская область      259          616         311
# 4                       Белгородская область       10           44          13
# 5                           Брянская область       13           80          16
# 6                       Владимирская область        1           84           5
# 7                      Волгоградская область     1587          478        1384
# 8                        Вологодская область        2            1           8
# 9                        Воронежская область     3250         1374        1461
# 10              Еврейская автономная область       71           76         115
# 11                        Забайкальский край      597          210         435
# 12                        Ивановская область     1081          348        2102
# 13                         Иркутская область      572          303        1276
# 14           Кабардино-Балкарская Республика        1            0           0
# 15                   Калининградская область     1660          950        2959
# 16                         Калужская область       20           32          35
# 17                           Камчатский край      620          107         518
# 18           Карачаево-Черкесская Республика      195           30          50
# 19                       Кемеровская область      393          712         469
# 20                         Кировская область       19           12          59
# 21                       Костромская область      507          142         111
# 22                        Краснодарский край     7225         5197         696
# 23                         Красноярский край     2955         1344        1111
# 24                        Курганская область        2            0           8
# 25                           Курская область     1589          577         228
# 26                     Ленинградская область     1567          101        1050
# 27                          Липецкая область      892          192         565
# 28                       Магаданская область       99           42         128
# 29                        Московская область     5439         2250        2495
# 30                        Мурманская область      150          356         133
# 31                 Ненецкий автономный округ        0            5           7
# 32                     Нижегородская область      557          268        1120
# 33                      Новгородская область      347          102         261
# 34                     Новосибирская область     2006         1348        2412
# 35                            Омская область       14           44         990
# 36                      Оренбургская область      218          111         298
# 37                         Орловская область      590          219         146
# 38                        Пензенская область        1            0          10
# 39                             Пермский край       31            4          51
# 40                           Приморский край     1547         1664         190
# 41                         Псковская область      359          118         567
# 42                         Республика Адыгея      241           54         132
# 43                          Республика Алтай     1162          445        1124
# 44                   Республика Башкортостан       36           30          50
# 45                        Республика Бурятия     1915          315         230
# 46                       Республика Дагестан      584          150         179
# 47                      Республика Ингушетия       68           20          11
# 48                       Республика Калмыкия       11           36           9
# 49                        Республика Карелия       36           64         202
# 50                           Республика Коми     1418          429        3354
# 51                           Республика Крым        0            0           1
# 52                       Республика Марий Эл      591          161         713
# 53                       Республика Мордовия        0            3           1
# 54                  Республика Саха (Якутия)        5            2          30
# 55       Республика Северная Осетия - Алания      157          115          11
# 56                      Республика Татарстан     4310         1023        2020
# 57                           Республика Тыва      766           95         158
# 58                        Республика Хакасия        4            0           7
# 59                        Ростовская область     1047          872        1442
# 60                         Рязанская область     2880          832        2605
# 61                         Самарская область     1008         1061        1268
# 62                       Саратовская область     1630          195        1089
# 63                       Сахалинская область      436          274         148
# 64                      Свердловская область      743          730        1513
# 65                        Смоленская область      561          217          20
# 66                       Ставропольский край      640          460         707
# 67                        Тамбовская область      329           92          90
# 68                          Тверская область      259          187         508
# 69                           Томская область      416          191        1651
# 70                          Тульская область      593          179         335
# 71                         Тюменская область     1760         1430        1812
# 72                     Удмуртская Республика       86           40         146
# 73                       Ульяновская область     1090          143         335
# 74                          Хабаровский край      923          235         517
# 75  Ханты-Мансийский автономный округ - Югра     7627         4728        5751
# 76                       Челябинская область     1383         8222        2033
# 77                      Чеченская Республика     3052          572          62
# 78                      Чувашская Республика     1841          285         193
# 79                Чукотский автономный округ        2            1           0
# 80           Ямало-Ненецкий автономный округ       31            6          73
# 81                       Ярославская область      424          340         641
# 82                                 г. Москва     1212         4055        1231
# 83                        г. Санкт-Петербург     1412          648        1258
# 84                            г. Севастополь     1232          211         470
# CPU times: total: 1.05 s
# Wall time: 4.18 s
