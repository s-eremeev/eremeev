# %%
import sqlite3, os

# заливка картинок-шаблонов в db
img_path = "C:/work/new_bot/img/img_source/"
conn = sqlite3.connect(r"C:\work\new_bot\img\db_img.sqlite")
cur = conn.cursor()
query = """INSERT INTO images (id, image) VALUES (?, ?)"""

for img in os.listdir(img_path):
    id = img
    i_path = img_path+img
    with open(i_path, 'rb') as file:
        blob_data = file.read()
    data = (id, blob_data)
    cur.execute(query, data)
    conn.commit()
cur.close()

# теперь они там

# %%
# извлечение картинок-шаблонов во временную папку
# tmp_path = "C:/work/new_bot/img/img_bilding/"
# conn = sqlite3.connect(r"C:\work\new_bot\img\db_img.sqlite")
# cur = conn.cursor()
# query = """SELECT * FROM images"""
# cur.execute(query)

# %%
# ПРАВИЛЬНОЕ РАЗМЕЩЕНИЕ ДАТЫ НА КАРТИНКЕ

from PIL import Image
from PIL import Image, ImageDraw, ImageFont
import os

im = Image.open("C:/work/new_bot/img/rus/rus_0.png")
draw_text = ImageDraw.Draw(im)
font_date = ImageFont.truetype("C:/work/new_bot/img/font/Montserrat.ttf", size=50)
# now = date.today().strftime("%d.%m.%Y")
date_str = "1 августа 2024"
draw_text.text((135, 880), date_str, fill=("#444444"), font=font_date)
im.show()
# im.close()

# %%
from PIL import Image
from PIL import Image, ImageDraw, ImageFont
import os

sub_path = "C:/work/new_bot/img/sub/"
rus_path = "C:/work/new_bot/img/rus/"
save_parh = "C:/work/new_bot/img/save/"
font_date = ImageFont.truetype("C:/work/new_bot/img/font/Montserrat.ttf", size=50)

data_dict = {
    # "января": [31, 1],
    # "февраля": [29, 2],
    # "марта": [31, 3],
    # "апреля": [30, 4],
    # "мая": [31, 5],
    # "июня": [30, 6],
    # "июля": [31, 7],
    # "августа": [31, 8],
    "сентября": [30, 9],
    # "октября": [31, 10],
    # "ноября": [30, 11],
    # "декабря": [31, 12],
}

sub_dict = {
    "sub_0": ["m0d", "M0"],
    "sub_1": ["m1d", "M1"],
    "sub_2": ["m2d", "M2"],
    "sub_3": ["m3d", "M3"],
    "sub_4": ["m4d", "M4"],
}

rus_dict = {
    "rus_0": ["Запись к врачу_Динамика показателей_", "Запись к врачу_Динамика показателей"],
    "rus_1": ["Запись к врачу_Ситуация в субъектах_", "Запись к врачу_Ситуация в субъектах"],
    "rus_2": ["Запись к врачу_Статистика ФЭР по РФ_", "Запись к врачу_Статистика ФЭР по РФ"],
    "rus_3": ["Запись к врачу_Технические ошибки_", "Запись к врачу_Технические ошибки"],
}

year_four = "2024"
year_two = "24"

for key, lst in data_dict.items():
    month_name = key
    month_number = "0"+str(lst[1]) if lst[1]<10 else str(lst[1])
    for i in range(1, lst[0]+1):
        date_str = " ".join([str(i), month_name, year_four])
        day_number = "0"+str(i) if i<10 else str(i)
        for img in os.listdir(sub_path):
            img_path = "".join([sub_path, img])
            img_preffix = img.split(".")[0]
            img_file_name = "".join([sub_dict.get(img_preffix)[0], day_number, month_number, year_two, ".png"])
            save_path = "".join([save_parh, sub_dict.get(img_preffix)[1], "/", img_file_name])
            im = Image.open(img_path)
            draw_text = ImageDraw.Draw(im)
            draw_text.text((135, 880), date_str, fill=("#444444"), font=font_date)
            im.save(save_path)
            print(save_path)
            # break # папки
        for img in os.listdir(rus_path):
            img_path = "".join([rus_path, img])
            img_preffix = img.split(".")[0]
            img_file_name = "".join([rus_dict.get(img_preffix)[0], day_number, ".png"])
            save_path = "".join([save_parh, rus_dict.get(img_preffix)[1], "/", img_file_name])
            im = Image.open(img_path)
            draw_text = ImageDraw.Draw(im)
            draw_text.text((135, 880), date_str, fill=("#444444"), font=font_date)
            im.save(save_path)
            print(save_path)
            print(save_path)
            # break # папки
    break # месяц
# Out:
# C:/work/new_bot/img/save/M0/m0d010924.png
# C:/work/new_bot/img/save/M1/m1d010924.png
# C:/work/new_bot/img/save/M2/m2d010924.png
# C:/work/new_bot/img/save/M3/m3d010924.png
# C:/work/new_bot/img/save/M4/m4d010924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_01.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_01.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_01.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_01.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_01.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_01.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_01.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_01.png
# C:/work/new_bot/img/save/M0/m0d020924.png
# C:/work/new_bot/img/save/M1/m1d020924.png
# C:/work/new_bot/img/save/M2/m2d020924.png
# C:/work/new_bot/img/save/M3/m3d020924.png
# C:/work/new_bot/img/save/M4/m4d020924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_02.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_02.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_02.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_02.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_02.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_02.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_02.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_02.png
# C:/work/new_bot/img/save/M0/m0d030924.png
# C:/work/new_bot/img/save/M1/m1d030924.png
# C:/work/new_bot/img/save/M2/m2d030924.png
# C:/work/new_bot/img/save/M3/m3d030924.png
# C:/work/new_bot/img/save/M4/m4d030924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_03.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_03.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_03.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_03.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_03.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_03.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_03.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_03.png
# C:/work/new_bot/img/save/M0/m0d040924.png
# C:/work/new_bot/img/save/M1/m1d040924.png
# C:/work/new_bot/img/save/M2/m2d040924.png
# C:/work/new_bot/img/save/M3/m3d040924.png
# C:/work/new_bot/img/save/M4/m4d040924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_04.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_04.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_04.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_04.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_04.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_04.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_04.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_04.png
# C:/work/new_bot/img/save/M0/m0d050924.png
# C:/work/new_bot/img/save/M1/m1d050924.png
# C:/work/new_bot/img/save/M2/m2d050924.png
# C:/work/new_bot/img/save/M3/m3d050924.png
# C:/work/new_bot/img/save/M4/m4d050924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_05.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_05.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_05.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_05.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_05.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_05.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_05.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_05.png
# C:/work/new_bot/img/save/M0/m0d060924.png
# C:/work/new_bot/img/save/M1/m1d060924.png
# C:/work/new_bot/img/save/M2/m2d060924.png
# C:/work/new_bot/img/save/M3/m3d060924.png
# C:/work/new_bot/img/save/M4/m4d060924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_06.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_06.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_06.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_06.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_06.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_06.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_06.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_06.png
# C:/work/new_bot/img/save/M0/m0d070924.png
# C:/work/new_bot/img/save/M1/m1d070924.png
# C:/work/new_bot/img/save/M2/m2d070924.png
# C:/work/new_bot/img/save/M3/m3d070924.png
# C:/work/new_bot/img/save/M4/m4d070924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_07.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_07.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_07.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_07.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_07.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_07.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_07.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_07.png
# C:/work/new_bot/img/save/M0/m0d080924.png
# C:/work/new_bot/img/save/M1/m1d080924.png
# C:/work/new_bot/img/save/M2/m2d080924.png
# C:/work/new_bot/img/save/M3/m3d080924.png
# C:/work/new_bot/img/save/M4/m4d080924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_08.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_08.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_08.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_08.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_08.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_08.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_08.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_08.png
# C:/work/new_bot/img/save/M0/m0d090924.png
# C:/work/new_bot/img/save/M1/m1d090924.png
# C:/work/new_bot/img/save/M2/m2d090924.png
# C:/work/new_bot/img/save/M3/m3d090924.png
# C:/work/new_bot/img/save/M4/m4d090924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_09.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_09.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_09.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_09.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_09.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_09.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_09.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_09.png
# C:/work/new_bot/img/save/M0/m0d100924.png
# C:/work/new_bot/img/save/M1/m1d100924.png
# C:/work/new_bot/img/save/M2/m2d100924.png
# C:/work/new_bot/img/save/M3/m3d100924.png
# C:/work/new_bot/img/save/M4/m4d100924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_10.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_10.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_10.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_10.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_10.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_10.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_10.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_10.png
# C:/work/new_bot/img/save/M0/m0d110924.png
# C:/work/new_bot/img/save/M1/m1d110924.png
# C:/work/new_bot/img/save/M2/m2d110924.png
# C:/work/new_bot/img/save/M3/m3d110924.png
# C:/work/new_bot/img/save/M4/m4d110924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_11.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_11.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_11.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_11.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_11.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_11.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_11.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_11.png
# C:/work/new_bot/img/save/M0/m0d120924.png
# C:/work/new_bot/img/save/M1/m1d120924.png
# C:/work/new_bot/img/save/M2/m2d120924.png
# C:/work/new_bot/img/save/M3/m3d120924.png
# C:/work/new_bot/img/save/M4/m4d120924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_12.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_12.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_12.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_12.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_12.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_12.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_12.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_12.png
# C:/work/new_bot/img/save/M0/m0d130924.png
# C:/work/new_bot/img/save/M1/m1d130924.png
# C:/work/new_bot/img/save/M2/m2d130924.png
# C:/work/new_bot/img/save/M3/m3d130924.png
# C:/work/new_bot/img/save/M4/m4d130924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_13.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_13.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_13.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_13.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_13.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_13.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_13.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_13.png
# C:/work/new_bot/img/save/M0/m0d140924.png
# C:/work/new_bot/img/save/M1/m1d140924.png
# C:/work/new_bot/img/save/M2/m2d140924.png
# C:/work/new_bot/img/save/M3/m3d140924.png
# C:/work/new_bot/img/save/M4/m4d140924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_14.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_14.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_14.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_14.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_14.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_14.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_14.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_14.png
# C:/work/new_bot/img/save/M0/m0d150924.png
# C:/work/new_bot/img/save/M1/m1d150924.png
# C:/work/new_bot/img/save/M2/m2d150924.png
# C:/work/new_bot/img/save/M3/m3d150924.png
# C:/work/new_bot/img/save/M4/m4d150924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_15.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_15.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_15.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_15.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_15.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_15.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_15.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_15.png
# C:/work/new_bot/img/save/M0/m0d160924.png
# C:/work/new_bot/img/save/M1/m1d160924.png
# C:/work/new_bot/img/save/M2/m2d160924.png
# C:/work/new_bot/img/save/M3/m3d160924.png
# C:/work/new_bot/img/save/M4/m4d160924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_16.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_16.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_16.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_16.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_16.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_16.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_16.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_16.png
# C:/work/new_bot/img/save/M0/m0d170924.png
# C:/work/new_bot/img/save/M1/m1d170924.png
# C:/work/new_bot/img/save/M2/m2d170924.png
# C:/work/new_bot/img/save/M3/m3d170924.png
# C:/work/new_bot/img/save/M4/m4d170924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_17.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_17.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_17.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_17.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_17.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_17.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_17.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_17.png
# C:/work/new_bot/img/save/M0/m0d180924.png
# C:/work/new_bot/img/save/M1/m1d180924.png
# C:/work/new_bot/img/save/M2/m2d180924.png
# C:/work/new_bot/img/save/M3/m3d180924.png
# C:/work/new_bot/img/save/M4/m4d180924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_18.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_18.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_18.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_18.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_18.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_18.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_18.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_18.png
# C:/work/new_bot/img/save/M0/m0d190924.png
# C:/work/new_bot/img/save/M1/m1d190924.png
# C:/work/new_bot/img/save/M2/m2d190924.png
# C:/work/new_bot/img/save/M3/m3d190924.png
# C:/work/new_bot/img/save/M4/m4d190924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_19.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_19.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_19.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_19.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_19.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_19.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_19.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_19.png
# C:/work/new_bot/img/save/M0/m0d200924.png
# C:/work/new_bot/img/save/M1/m1d200924.png
# C:/work/new_bot/img/save/M2/m2d200924.png
# C:/work/new_bot/img/save/M3/m3d200924.png
# C:/work/new_bot/img/save/M4/m4d200924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_20.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_20.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_20.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_20.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_20.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_20.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_20.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_20.png
# C:/work/new_bot/img/save/M0/m0d210924.png
# C:/work/new_bot/img/save/M1/m1d210924.png
# C:/work/new_bot/img/save/M2/m2d210924.png
# C:/work/new_bot/img/save/M3/m3d210924.png
# C:/work/new_bot/img/save/M4/m4d210924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_21.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_21.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_21.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_21.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_21.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_21.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_21.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_21.png
# C:/work/new_bot/img/save/M0/m0d220924.png
# C:/work/new_bot/img/save/M1/m1d220924.png
# C:/work/new_bot/img/save/M2/m2d220924.png
# C:/work/new_bot/img/save/M3/m3d220924.png
# C:/work/new_bot/img/save/M4/m4d220924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_22.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_22.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_22.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_22.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_22.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_22.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_22.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_22.png
# C:/work/new_bot/img/save/M0/m0d230924.png
# C:/work/new_bot/img/save/M1/m1d230924.png
# C:/work/new_bot/img/save/M2/m2d230924.png
# C:/work/new_bot/img/save/M3/m3d230924.png
# C:/work/new_bot/img/save/M4/m4d230924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_23.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_23.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_23.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_23.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_23.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_23.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_23.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_23.png
# C:/work/new_bot/img/save/M0/m0d240924.png
# C:/work/new_bot/img/save/M1/m1d240924.png
# C:/work/new_bot/img/save/M2/m2d240924.png
# C:/work/new_bot/img/save/M3/m3d240924.png
# C:/work/new_bot/img/save/M4/m4d240924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_24.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_24.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_24.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_24.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_24.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_24.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_24.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_24.png
# C:/work/new_bot/img/save/M0/m0d250924.png
# C:/work/new_bot/img/save/M1/m1d250924.png
# C:/work/new_bot/img/save/M2/m2d250924.png
# C:/work/new_bot/img/save/M3/m3d250924.png
# C:/work/new_bot/img/save/M4/m4d250924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_25.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_25.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_25.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_25.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_25.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_25.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_25.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_25.png
# C:/work/new_bot/img/save/M0/m0d260924.png
# C:/work/new_bot/img/save/M1/m1d260924.png
# C:/work/new_bot/img/save/M2/m2d260924.png
# C:/work/new_bot/img/save/M3/m3d260924.png
# C:/work/new_bot/img/save/M4/m4d260924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_26.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_26.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_26.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_26.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_26.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_26.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_26.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_26.png
# C:/work/new_bot/img/save/M0/m0d270924.png
# C:/work/new_bot/img/save/M1/m1d270924.png
# C:/work/new_bot/img/save/M2/m2d270924.png
# C:/work/new_bot/img/save/M3/m3d270924.png
# C:/work/new_bot/img/save/M4/m4d270924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_27.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_27.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_27.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_27.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_27.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_27.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_27.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_27.png
# C:/work/new_bot/img/save/M0/m0d280924.png
# C:/work/new_bot/img/save/M1/m1d280924.png
# C:/work/new_bot/img/save/M2/m2d280924.png
# C:/work/new_bot/img/save/M3/m3d280924.png
# C:/work/new_bot/img/save/M4/m4d280924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_28.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_28.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_28.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_28.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_28.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_28.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_28.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_28.png
# C:/work/new_bot/img/save/M0/m0d290924.png
# C:/work/new_bot/img/save/M1/m1d290924.png
# C:/work/new_bot/img/save/M2/m2d290924.png
# C:/work/new_bot/img/save/M3/m3d290924.png
# C:/work/new_bot/img/save/M4/m4d290924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_29.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_29.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_29.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_29.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_29.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_29.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_29.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_29.png
# C:/work/new_bot/img/save/M0/m0d300924.png
# C:/work/new_bot/img/save/M1/m1d300924.png
# C:/work/new_bot/img/save/M2/m2d300924.png
# C:/work/new_bot/img/save/M3/m3d300924.png
# C:/work/new_bot/img/save/M4/m4d300924.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_30.png
# C:/work/new_bot/img/save/Запись к врачу_Динамика показателей/Запись к врачу_Динамика показателей_30.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_30.png
# C:/work/new_bot/img/save/Запись к врачу_Ситуация в субъектах/Запись к врачу_Ситуация в субъектах_30.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_30.png
# C:/work/new_bot/img/save/Запись к врачу_Статистика ФЭР по РФ/Запись к врачу_Статистика ФЭР по РФ_30.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_30.png
# C:/work/new_bot/img/save/Запись к врачу_Технические ошибки/Запись к врачу_Технические ошибки_30.png

# %%
# import excel2img
# excel2img.export_img("example.xlsx/example.csv","image.png/image.bmp","sheet!B2:H22")

import excel2img
excel2img.export_img("C:/Users/Admin/Desktop/ДЭЗ_240804_02.xlsm", "C:/Users/Admin/Desktop/test.png", "Рейтинг_МО!A1:D33")
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\excel2img\excel2img.py:88, in export_img(fn_excel, fn_image, page, _range)
#      87 try:
# ---> 88     rng = excel.workbook.Sheets(page).UsedRange
#      89 except com_error:
#
# File ~\AppData\Local\Temp\gen_py\3.11\00020813-0000-0000-C000-000000000046x0x1x9.py:36707, in Sheets.__call__(self, Index)
#   36706 def __call__(self, Index=defaultNamedNotOptArg):
# > 36707 	ret = self._oleobj_.InvokeTypes(0, LCID, 2, (9, 0), ((12, 1),),Index
#   36708 		)
#   36709 	if ret is not None:
#
# com_error: (-2147352567, 'Ошибка.', (0, None, None, None, 0, -2147352565), None)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # import excel2img
#       2 # excel2img.export_img("example.xlsx/example.csv","image.png/image.bmp","sheet!B2:H22")
#       4 import excel2img
# ----> 5 excel2img.export_img("C:/Users/Admin/Desktop/ДЭЗ_240804_02.xlsm", "C:/Users/Admin/Desktop/test.png", "Рейтинг_МО!A1:D33")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\excel2img\excel2img.py:90, in export_img(fn_excel, fn_image, page, _range)
#      88     rng = excel.workbook.Sheets(page).UsedRange
#      89 except com_error:
# ---> 90     raise Exception("Failed locating used cell range on page %s"%page)
#      91 except AttributeError:
#      92     # This might be a "chart page", try exporting it as a whole
#      93     rng = excel.workbook.Sheets(page).Export(os.path.abspath(fn_image))
#
# Exception: Failed locating used cell range on page Рейтинг_МО!A1:D33

# %%
from PIL import ImageGrab
import numpy as np
import cv2

img = ImageGrab.grab(bbox=(100,10,400,780))
img.show()
